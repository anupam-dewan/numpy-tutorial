# %%
from numpy import loadtxt, sum, where,linspace
from matplotlib.pyplot import figure, hold, plot, show

# %%
OPEN = 0
HIGH = 1
LOW = 2
CLOSE = 3
VOLUME = 4
ADJ_CLOSE = 5

# %%
dow = loadtxt('dow.csv', delimiter=',')

# %%
mask = dow[:,4]>5500000000

# %%
selected=dow[mask,:]
selected.shape
# Out:
# (18, 6)

# %%
where(dow[:,4]>5500000000)
# Out:
# (array([ 12,  13,  15,  51,  54, 123, 125, 129, 131, 132, 134, 135, 136,
#         137, 139, 140, 141, 145], dtype=int64),)

# %%
y=dow[:,ADJ_CLOSE]
plot(y)

# %%
selected =dow[where(dow[:,4]>5500000000)]
y1=selected[:,ADJ_CLOSE]
plot(y1,'r-')
show()
